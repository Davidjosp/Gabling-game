# %%
def game():
    import math
    import random
    x = [0,1,3,4,2,6,7,8,9]
    money=0
    account=500
    ewallet=5000
    count=0
    while 1:
        if (account<500) and (count==0):
            r=random.choice(x)
            print("you need 500 to play the game your ballance:",account,"\newallet balance:",ewallet)
            money=int(input("enetr the amount to be added to account:"))
            account += money
            ewallet -= money
            prize=0
            if (account<500):
                continue
        if (account>=500) and (count==0):
            r=random.choice(x)
            prize=0
        y=int(input("guss the number:"))
        if(y==r)  and (count==0):
            print("you got it right in first chance !!!!!!!!!")
            prize += 5000
            ewallet += prize
            print("prize money added to your ewallet\naccount balance:",account,"\newallet balance:",ewallet)
            a=input("\ndo you want to continue print y/n:")
            if(a=='y'):
                continue
            else:
                print("enjoy your day")
                break
        count += 1  
        if(y==r) and (count==2):
            print("you got it right")
            prize += 1000
            ewallet += prize
            count=0
            print("prize money 1000 added to your ewallet\naccount balance:",account,"\newallet balance:",ewallet)
            b=input("\ndo you want to continue print y/n:")
            if(b=='y'):
                continue
            else:
                print("enjoy your day")
                break 
            
        if(y==r):
            print("you got it right")
            count=0
            print("no prize money as you lost in first two chances\naccount balance:",account,"\newallet balance:",ewallet)
            b=input("\ndo you want to continue print y/n:")
            if(b=='y'):
                continue
            else:
                print("enjoy your day")
                break 
                    
        if(y!=r):
            print("sorry try again")
            print("you have",3-count,"chances")
            if(y<r):
                print("enetrd value low")
            else:
                print("enterd value high")
        if(count==3):
            account= account- 500
            count=0
            print("you have lost all chances")
            print("account balance:",account,"\newallet balance:",ewallet)
            c=input("\ndo you want to continue print y/n:")
            if(c=='y'):
                continue
            else:
                print("enjoy your day")
                break

# %%
game()
# Out:
# guss the number:5
# sorry try again
# you have 2 chances
# enetrd value low
# guss the number:8
# sorry try again
# you have 1 chances
# enterd value high
# guss the number:7
# you got it right
# no prize money as you lost in first two chances
# account balance: 500
# ewallet balance: 5000
#
# do you want to continue print y/n:y
# guss the number:5
# sorry try again
# you have 2 chances
# enetrd value low
# guss the number:7
# sorry try again
# you have 1 chances
# enetrd value low
# guss the number:8
# sorry try again
# you have 0 chances
# enetrd value low
# you have lost all chances
# account balance: 0
# ewallet balance: 5000
#
# do you want to continue print y/n:y
# you need 500 to play the game your ballance: 0
# ewallet balance: 5000
# enetr the amount to be added to account:200
# you need 500 to play the game your ballance: 200
# ewallet balance: 4800
# enetr the amount to be added to account:300
# guss the number:5
# sorry try again
# you have 2 chances
# enetrd value low
# ...
